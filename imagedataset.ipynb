# %%
from google.colab import drive
#for accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['0.jpg']))
import matplotlib.pyplot as plt

plt.imshow(im)
plt.show()
# Out:
#      <input type="file" id="files-3a531ebf-b1fe-4e0e-b172-1e94dbb7ebbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a531ebf-b1fe-4e0e-b172-1e94dbb7ebbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0.jpg to 0.jpg

# %%
import cv2
import os


def load_images_from_folder(folder):
  images=[]
  for filename in os.listdir(folder):
    img=cv2.imread(os.path.join(folder,filename))
    if img is not None:
      images.append(img)
  return images
folder="/content/drive/My Drive/images"
image=load_images_from_folder(folder)
load_images_from_folder(folder)

# %%
A=[]

folder_length=len(folder)-1;

for x in range(len(folder)):
  if folder[folder_length]=='/':
    break
  else:
    A.append(folder[folder_length])
  folder_length=folder_length-1
A.reverse()
s = ""
s = s.join(A)

print(s)
# Out:
# images

# %%
#finding the labels of subfolders in root and conctenating the subfolders each with the path
import os
folder="/content/drive/My Drive/images"
l=os.listdir(folder)

a=[]
for root,dirs,files in os.walk(folder):
  a.append(dirs)
for n in range(len(a[0])):  
  newPath=folder+'/'+a[0][n]
  print(newPath)
# Out:
# /content/drive/My Drive/images/informal
# /content/drive/My Drive/images/formal
